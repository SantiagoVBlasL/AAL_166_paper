# %%
# !python tensor_viewer.py
# Out:
# --- CASO 1: Visualizando Promedio Global para TODOS los Canales ---
# Cargando tensor desde: GLOBAL_TENSOR_from_AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.21_AAL3_131ROIs_OMST_GCE_Signed_Granger_lag1__ChNorm_ROIreorderedYeo17_ParallelTuned.npz
#
# --- Metadatos Cargados ---
#   - subject_ids: array de forma (431,), tipo <U10
#   - channel_names: array de forma (5,), tipo <U32
#     Contenido: ['Pearson_OMST_GCE_Signed_Weighted' 'MI_KNN_Symmetric' 'dFC_AbsDiffMean'
#  'dFC_StdDev' 'Granger_F_lag1']
#   - rois_count: array de forma (), tipo int64
#     Contenido: 131
#   - tr_seconds: array de forma (), tipo float64
#     Contenido: 3.0
#   - filter_low_hz: array de forma (), tipo float64
#     Contenido: 0.01
#   - filter_high_hz: array de forma (), tipo float64
#     Contenido: 0.08
#   - hrf_deconvolution_applied: array de forma (), tipo bool
#     Contenido: False
#   - hrf_model: array de forma (), tipo <U3
#     Contenido: N/A
# ...
