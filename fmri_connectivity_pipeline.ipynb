# %%
# !python fmri_connectivity_pipeline.py \
    --base_path_aal3 /home/diego/Escritorio/AAL3_paper \
    --qc_output_dir_name qc_outputs_doctoral_v3.2_aal3_shrinkage_flexible_thresh_fix \
    --subj_meta_csv SubjectsData_Schaefer2018_400ROIs.csv \
    --qc_report_csv report_qc_final_with_discard_flags_v3.2.csv \
    --roi_signals_dir ROISignalsAAL3 \
    --aal3_meta_path ROI_MNI_V7_vol.txt \
    --aal3_nifti_path /home/diego/Escritorio/AAL3/AAL3v1.nii.gz \
    --tr_seconds 3.0 \
    --low_cut_hz 0.01 \
    --high_cut_hz 0.08 \
    --filter_order 2 \
    --taper_alpha 0.1 \
    --apply_hrf_deconvolution false \
    --hrf_model glover \
    --raw_data_expected_columns 170 \
    --aal3_missing_indices_1based "35,36,81,82" \
    --small_roi_voxel_threshold 100 \
    --n_neighbors_mi 5 \
    --dfc_win_points_sec 90.0 \
    --dfc_step_sec 15.0 \
    --use_granger_channel true \
    --granger_max_lag 1 \
    --use_pearson_omst_channel true \
    --use_pearson_full_signed_channel true \
    --use_mi_channel_for_thesis true \
    --use_dfc_abs_diff_mean_channel true \
    --use_dfc_stddev_channel true \
    --max_workers 4 # Adjust as per your CPU cores, or remove to use default
# Out:
# 2025-06-14 14:04:51,739 - INFO - fmri_connectivity_pipeline.py:1518 - MAX_WORKERS explicitly set to: 4 via argparse.
# 2025-06-14 14:04:51,739 - INFO - fmri_connectivity_pipeline.py:1306 - --- Initializing AAL3 ROI Processing Information ---
# 2025-06-14 14:04:51,743 - INFO - fmri_connectivity_pipeline.py:1347 - AAL3 ROI processing info initialized (prior to reordering attempt):
# 2025-06-14 14:04:51,743 - INFO - fmri_connectivity_pipeline.py:1348 -   Indices of 4 AAL3 systemically missing ROIs (0-based, from 170): [34, 35, 80, 81]
# 2025-06-14 14:04:51,743 - INFO - fmri_connectivity_pipeline.py:1349 -   Number of ROIs in AAL3 meta after excluding systemically missing: 166 (Expected: 166)
# 2025-06-14 14:04:51,743 - INFO - fmri_connectivity_pipeline.py:1350 -   Indices of small ROIs to drop (from the 166 set, 0-based): [108, 116, 117, 118, 119, 120, 121, 126, 127, 128, 129, 132, 133, 134, 135, 136, 137, 138, 139, 142, 143, 144, 145, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165]
# 2025-06-14 14:04:51,743 - INFO - fmri_connectivity_pipeline.py:1351 -   Number of small ROIs to drop: 35
# 2025-06-14 14:04:51,743 - INFO - fmri_connectivity_pipeline.py:1352 -   FINAL_N_ROIS_EXPECTED for connectivity analysis: 131 (This should be 131 if matching QC script)
# 2025-06-14 14:04:51,743 - INFO - fmri_connectivity_pipeline.py:733 - Attempting to map AAL3 ROIs to Yeo-17 networks and reorder.
# 2025-06-14 14:04:51,743 - INFO - fmri_connectivity_pipeline.py:744 - Fetching Yeo 17-network atlas...
# 2025-06-14 14:04:51,977 - INFO - fmri_connectivity_pipeline.py:748 - Yeo-17 atlas loaded. Shape: (256, 256, 256, 1), Affine:
# [[  -1.    0.    0.  127.]
#  [   0.    0.    1. -145.]
#  [   0.   -1.    0.  147.]
#  [   0.    0.    0.    1.]]
# 2025-06-14 14:04:51,977 - INFO - fmri_connectivity_pipeline.py:750 - Loading AAL3 NIfTI from: /home/diego/Escritorio/AAL3/AAL3v1.nii.gz
# 2025-06-14 14:04:51,978 - INFO - fmri_connectivity_pipeline.py:752 - Original AAL3 NIfTI atlas loaded. Shape: (91, 109, 91), Affine:
# [[  -2.    0.    0.   90.]
#  [   0.    2.    0. -126.]
#  [   0.    0.    2.  -72.]
#  [   0.    0.    0.    1.]]
# 2025-06-14 14:04:51,978 - WARNING - fmri_connectivity_pipeline.py:755 - Affines or shapes of AAL3 and Yeo atlases do not match. Attempting to resample AAL3 to Yeo space using nearest neighbor interpolation.
# 2025-06-14 14:04:52,873 - INFO - fmri_connectivity_pipeline.py:760 - AAL3 atlas resampled. New Shape: (256, 256, 256), New Affine:
# [[  -1.    0.    0.  127.]
#  [   0.    0.    1. -145.]
#  [   0.   -1.    0.  147.]
#  [   0.    0.    0.    1.]]
# 2025-06-14 14:04:52,874 - INFO - fmri_connectivity_pipeline.py:778 - Mapping 131 AAL3 ROIs to Yeo-17 networks...
# 2025-06-14 14:06:03,132 - INFO - fmri_connectivity_pipeline.py:829 - Successfully mapped AAL3 ROIs to Yeo-17 networks and determined new ROI order.
# 2025-06-14 14:06:03,134 - INFO - fmri_connectivity_pipeline.py:836 - AAL3 to Yeo-17 mapping saved to: /home/diego/Escritorio/AAL3_paper/aal3_131_to_yeo17_mapping.csv
# 2025-06-14 14:06:03,140 - INFO - fmri_connectivity_pipeline.py:1365 - ROI reordering WILL BE APPLIED based on 'aal3_to_yeo17_overlap_sorted'.
# 2025-06-14 14:06:03,140 - INFO - fmri_connectivity_pipeline.py:1538 - RUNTIME NetworkX version being used: 2.6.3
# 2025-06-14 14:06:03,140 - INFO - fmri_connectivity_pipeline.py:1549 - Main process RAM at start: 283.09 MB
# 2025-06-14 14:06:03,140 - INFO - fmri_connectivity_pipeline.py:1550 - --- Starting fMRI Connectivity Pipeline (Version: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.21) ---
# 2025-06-14 14:06:03,140 - INFO - fmri_connectivity_pipeline.py:1556 - --- Final Expected ROIs for Connectivity Matrices: 131 ---
# 2025-06-14 14:06:03,140 - INFO - fmri_connectivity_pipeline.py:1557 - --- Output Directory Name: AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.21_AAL3_131ROIs_OMST_GCE_Signed_Granger_lag1__ChNorm_ROIreorderedYeo17_ParallelTuned ---
# 2025-06-14 14:06:03,140 - INFO - fmri_connectivity_pipeline.py:1558 - --- Selected Connectivity Channels for VAE: ['Pearson_OMST_GCE_Signed_Weighted', 'Pearson_Full_FisherZ_Signed', 'MI_KNN_Symmetric', 'dFC_AbsDiffMean', 'dFC_StdDev', 'Granger_F_lag1'] (6 channels) ---
# 2025-06-14 14:06:03,140 - INFO - fmri_connectivity_pipeline.py:1559 - --- Per-subject, per-channel normalization with RobustScaler (off-diagonal) will be applied before stacking. ---
# 2025-06-14 14:06:03,140 - INFO - fmri_connectivity_pipeline.py:1562 - --- ROI reordering by network is currently: ACTIVE (Yeo-17 mapping implemented). ---
# 2025-06-14 14:06:03,141 - INFO - fmri_connectivity_pipeline.py:1200 - --- Starting Subject Metadata Loading and QC Integration ---
# 2025-06-14 14:06:03,143 - INFO - fmri_connectivity_pipeline.py:1211 - Loaded main metadata from /home/diego/Escritorio/AAL3_paper/SubjectsData_Schaefer2018_400ROIs.csv. Shape: (434, 24)
# 2025-06-14 14:06:03,145 - INFO - fmri_connectivity_pipeline.py:1219 - Loaded QC report from /home/diego/Escritorio/AAL3_paper/qc_outputs_doctoral_v3.2_aal3_shrinkage_flexible_thresh_fix/report_qc_final_with_discard_flags_v3.2.csv. Shape: (434, 34)
# 2025-06-14 14:06:03,145 - INFO - fmri_connectivity_pipeline.py:1222 - Found 'Subject' column in QC report, renaming to 'SubjectID'.
# 2025-06-14 14:06:03,147 - INFO - fmri_connectivity_pipeline.py:1249 - SUGGESTION (Data Quality): Review 'ToDiscard_Overall' criteria from QC script. Consider if stricter thresholds for subject exclusion (e.g., based on percentage of multivariate outliers, mean FD, DVARS) would yield a cleaner dataset for modeling, even if N is slightly reduced. Ensure discard rate is similar across groups.
# 2025-06-14 14:06:03,147 - INFO - fmri_connectivity_pipeline.py:1255 - Total subjects after merge: 434
# 2025-06-14 14:06:03,147 - INFO - fmri_connectivity_pipeline.py:1256 - Subjects discarded based on QC ('ToDiscard_Overall' == True): 3
# 2025-06-14 14:06:03,147 - INFO - fmri_connectivity_pipeline.py:1257 - Subjects passing QC and to be processed: 431
# 2025-06-14 14:06:03,147 - INFO - fmri_connectivity_pipeline.py:1265 - Timepoints for subjects passing QC (from QC report): Min=140, Max=200.
# 2025-06-14 14:06:03,148 - INFO - fmri_connectivity_pipeline.py:1586 - Main output directory created/exists: /home/diego/Escritorio/AAL3_paper/AAL3_dynamicROIs_fmri_tensor_NeuroEnhanced_v6.5.21_AAL3_131ROIs_OMST_GCE_Signed_Granger_lag1__ChNorm_ROIreorderedYeo17_ParallelTuned
# 2025-06-14 14:06:03,148 - INFO - fmri_connectivity_pipeline.py:1590 - Total CPU cores available: 12. Using MAX_WORKERS = 4 for ProcessPoolExecutor.
# 2025-06-14 14:06:03,148 - WARNING - fmri_connectivity_pipeline.py:1592 - Available system RAM at start of parallel processing: 6.35 GB. Monitor usage closely.
# 2025-06-14 14:06:03,157 - INFO - fmri_connectivity_pipeline.py:1599 - Starting parallel processing for 431 subjects.
# 2025-06-14 14:06:03,181 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_0729: Starting processing pipeline.
# 2025-06-14 14:06:03,181 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_0295: Starting processing pipeline.
# 2025-06-14 14:06:03,182 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_0685: Starting processing pipeline.
# 2025-06-14 14:06:03,182 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_0413: Starting processing pipeline.
# Processing Subjects:   0%|                              | 0/431 [00:00<?, ?it/s]2025-06-14 14:06:03,296 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_0685: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:03,296 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_0295: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:03,296 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_0685: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:06:03,296 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_0295: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:06:03,296 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_0413: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:03,296 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_0413: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:06:03,297 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_0729: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:03,297 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_0729: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:06:03,394 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_0413: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:06:03,397 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_0729: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:06:03,401 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_0685: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:06:03,401 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_0295: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:06:51,329 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0729, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:06:51,329 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0729, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:51,329 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0729, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 47.93s.
# 2025-06-14 14:06:51,331 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0729, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:06:51,331 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0729, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:51,331 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0729, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:06:51,581 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0685, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:06:51,581 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0685, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:51,581 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0685, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 48.18s.
# 2025-06-14 14:06:51,583 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0685, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:06:51,583 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0685, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:51,583 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0685, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:06:51,798 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0413, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:06:51,798 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0413, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:51,798 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0413, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 48.40s.
# 2025-06-14 14:06:51,800 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0413, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:06:51,800 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0413, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:51,800 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0413, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:06:52,123 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0295, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:06:52,123 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0295, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:52,123 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0295, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 48.72s.
# 2025-06-14 14:06:52,125 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0295, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:06:52,125 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0295, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:06:52,125 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0295, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:07:10,623 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0685, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:10,623 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0685, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:10,623 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0685, Channel MI_KNN_Symmetric: Calculated in 19.04s.
# 2025-06-14 14:07:10,629 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0685, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:10,629 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0685, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:10,630 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0685, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 14:07:10,638 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0685, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:10,638 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0685, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:10,638 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0685, Channel dFC_StdDev: Calculated in 0.01s.
# 2025-06-14 14:07:10,857 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0729, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:10,857 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0729, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:10,857 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0729, Channel MI_KNN_Symmetric: Calculated in 19.53s.
# 2025-06-14 14:07:10,864 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0729, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:10,864 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0729, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:10,864 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0729, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 14:07:10,874 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0729, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:10,874 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0729, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:10,874 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0729, Channel dFC_StdDev: Calculated in 0.01s.
# 2025-06-14 14:07:11,520 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0295, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:11,521 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0295, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:11,521 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0295, Channel MI_KNN_Symmetric: Calculated in 19.40s.
# 2025-06-14 14:07:11,537 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0295, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:11,537 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0295, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:11,538 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0295, Channel dFC_AbsDiffMean: Calculated in 0.02s.
# 2025-06-14 14:07:11,568 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0295, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:11,568 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0295, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:11,569 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0295, Channel dFC_StdDev: Calculated in 0.03s.
# 2025-06-14 14:07:11,723 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0413, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:11,726 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0413, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:11,726 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0413, Channel MI_KNN_Symmetric: Calculated in 19.93s.
# 2025-06-14 14:07:11,792 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0413, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:11,792 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0413, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:11,792 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0413, Channel dFC_AbsDiffMean: Calculated in 0.07s.
# 2025-06-14 14:07:11,818 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0413, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:07:11,818 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0413, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:07:11,818 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0413, Channel dFC_StdDev: Calculated in 0.03s.
# 2025-06-14 14:08:02,526 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0729, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:02,530 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0729, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:02,531 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0729, Channel Granger_F_lag1: Calculated in 51.66s.
# 2025-06-14 14:08:02,702 - INFO - fmri_connectivity_pipeline.py:709 - S 002_S_0729: Tensor saved to subject_002_S_0729_conn_tensor.npz in 0.01s.
# Processing Subjects:   0%|                  | 1/431 [01:59<14:16:55, 119.57s/it]2025-06-14 14:08:02,757 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_1155: Starting processing pipeline.
# 2025-06-14 14:08:02,808 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_1155: Reordenando series temporales de ROIs ((197, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:02,813 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_1155: Preprocessing. Input TPs: 197, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:08:02,916 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_1155: Successfully loaded and preprocessed. Original TPs: 197, Final Shape for conn: (197, 131)
# 2025-06-14 14:08:03,612 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0295, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:03,612 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0295, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:03,612 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0295, Channel Granger_F_lag1: Calculated in 52.04s.
# 2025-06-14 14:08:03,781 - INFO - fmri_connectivity_pipeline.py:709 - S 002_S_0295: Tensor saved to subject_002_S_0295_conn_tensor.npz in 0.02s.
# Processing Subjects:   0%|                    | 2/431 [02:00<5:56:35, 49.87s/it]2025-06-14 14:08:03,840 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_2010: Starting processing pipeline.
# 2025-06-14 14:08:03,893 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0413, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:03,893 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0413, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:03,893 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0413, Channel Granger_F_lag1: Calculated in 52.08s.
# 2025-06-14 14:08:03,899 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_2010: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:03,900 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_2010: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:08:03,976 - INFO - fmri_connectivity_pipeline.py:709 - S 002_S_0413: Tensor saved to subject_002_S_0413_conn_tensor.npz in 0.02s.
# 2025-06-14 14:08:03,979 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_2010: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# Processing Subjects:   1%|▏                   | 3/431 [02:00<3:13:59, 27.20s/it]2025-06-14 14:08:04,051 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_2043: Starting processing pipeline.
# 2025-06-14 14:08:04,125 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_2043: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:04,126 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_2043: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:08:04,226 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_2043: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:08:05,352 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_0685, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:05,352 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_0685, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:05,352 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_0685, Channel Granger_F_lag1: Calculated in 54.71s.
# 2025-06-14 14:08:05,429 - INFO - fmri_connectivity_pipeline.py:709 - S 002_S_0685: Tensor saved to subject_002_S_0685_conn_tensor.npz in 0.01s.
# Processing Subjects:   1%|▏                   | 4/431 [02:02<2:01:11, 17.03s/it]2025-06-14 14:08:05,492 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_2073: Starting processing pipeline.
# 2025-06-14 14:08:05,553 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_2073: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:05,554 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_2073: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:08:05,623 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_2073: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:08:49,914 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_1155, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:49,914 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_1155, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:49,914 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_1155, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 47.00s.
# 2025-06-14 14:08:49,916 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_1155, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:49,916 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_1155, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:49,917 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_1155, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:08:50,047 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2010, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:50,047 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2010, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:50,047 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2010, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 46.07s.
# 2025-06-14 14:08:50,049 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2010, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:50,049 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2010, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:50,049 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2010, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:08:50,429 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2043, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:50,429 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2043, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:50,429 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2043, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 46.20s.
# 2025-06-14 14:08:50,431 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2043, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:50,431 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2043, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:50,431 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2043, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:08:51,899 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2073, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:51,899 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2073, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:51,900 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2073, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 46.28s.
# 2025-06-14 14:08:51,901 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2073, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:08:51,901 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2073, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:08:51,901 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2073, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:09:09,358 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2010, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:09,358 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2010, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:09,359 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2010, Channel MI_KNN_Symmetric: Calculated in 19.31s.
# 2025-06-14 14:09:09,365 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2010, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:09,365 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2010, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:09,365 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2010, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 14:09:09,371 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2010, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:09,371 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2010, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:09,371 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2010, Channel dFC_StdDev: Calculated in 0.01s.
# 2025-06-14 14:09:10,347 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2043, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:10,347 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2043, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:10,347 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2043, Channel MI_KNN_Symmetric: Calculated in 19.92s.
# 2025-06-14 14:09:10,358 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2043, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:10,358 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2043, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:10,358 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2043, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 14:09:10,381 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2043, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:10,381 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2043, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:10,381 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2043, Channel dFC_StdDev: Calculated in 0.02s.
# 2025-06-14 14:09:11,448 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2073, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:11,448 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2073, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:11,448 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2073, Channel MI_KNN_Symmetric: Calculated in 19.55s.
# 2025-06-14 14:09:11,454 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2073, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:11,454 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2073, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:11,454 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2073, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 14:09:11,472 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2073, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:11,472 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2073, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:11,472 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2073, Channel dFC_StdDev: Calculated in 0.02s.
# 2025-06-14 14:09:12,367 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_1155, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:12,367 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_1155, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:12,368 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_1155, Channel MI_KNN_Symmetric: Calculated in 22.45s.
# 2025-06-14 14:09:12,381 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_1155, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:12,381 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_1155, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:12,382 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_1155, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 14:09:12,403 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_1155, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:12,403 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_1155, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:12,403 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_1155, Channel dFC_StdDev: Calculated in 0.02s.
# 2025-06-14 14:09:53,998 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2010, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:53,999 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2010, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:53,999 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2010, Channel Granger_F_lag1: Calculated in 44.63s.
# 2025-06-14 14:09:54,073 - INFO - fmri_connectivity_pipeline.py:709 - S 002_S_2010: Tensor saved to subject_002_S_2010_conn_tensor.npz in 0.02s.
# Processing Subjects:   1%|▏                   | 5/431 [03:50<5:55:28, 50.07s/it]2025-06-14 14:09:54,140 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_4171: Starting processing pipeline.
# 2025-06-14 14:09:54,201 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_4171: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:54,202 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_4171: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:09:54,289 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_4171: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:09:57,323 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2043, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:57,323 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2043, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:57,324 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2043, Channel Granger_F_lag1: Calculated in 46.94s.
# 2025-06-14 14:09:57,384 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_1155, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 14:09:57,387 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_1155, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:57,387 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_1155, Channel Granger_F_lag1: Calculated in 44.98s.
# 2025-06-14 14:09:57,442 - INFO - fmri_connectivity_pipeline.py:709 - S 002_S_2043: Tensor saved to subject_002_S_2043_conn_tensor.npz in 0.03s.
# 2025-06-14 14:09:57,503 - INFO - fmri_connectivity_pipeline.py:709 - S 002_S_1155: Tensor saved to subject_002_S_1155_conn_tensor.npz in 0.01s.
# 2025-06-14 14:09:57,523 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_4213: Starting processing pipeline.
# Processing Subjects:   1%|▎                   | 6/431 [03:54<4:02:12, 34.19s/it]2025-06-14 14:09:57,568 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_4219: Starting processing pipeline.
# 2025-06-14 14:09:57,589 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_4213: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:57,589 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_4213: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:09:57,615 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_4219: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:09:57,615 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_4219: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:09:57,674 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_4213: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:09:57,698 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_4219: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:10:00,810 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_2073, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 14:10:00,810 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_2073, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:00,811 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_2073, Channel Granger_F_lag1: Calculated in 49.34s.
# 2025-06-14 14:10:00,886 - INFO - fmri_connectivity_pipeline.py:709 - S 002_S_2073: Tensor saved to subject_002_S_2073_conn_tensor.npz in 0.01s.
# Processing Subjects:   2%|▎                   | 8/431 [03:57<2:08:13, 18.19s/it]2025-06-14 14:10:00,946 - INFO - fmri_connectivity_pipeline.py:544 - S 002_S_4229: Starting processing pipeline.
# 2025-06-14 14:10:01,015 - INFO - fmri_connectivity_pipeline.py:863 - S 002_S_4229: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:01,015 - INFO - fmri_connectivity_pipeline.py:1075 - S 002_S_4229: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 14:10:01,105 - INFO - fmri_connectivity_pipeline.py:1188 - S 002_S_4229: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 14:10:43,028 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4171, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:10:43,028 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4171, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:43,028 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4171, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 48.74s.
# 2025-06-14 14:10:43,030 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4171, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:10:43,030 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4171, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:43,030 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4171, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:10:43,781 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4219, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:10:43,781 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4219, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:43,781 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4219, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 46.08s.
# 2025-06-14 14:10:43,783 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4219, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:10:43,783 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4219, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:43,783 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4219, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:10:44,896 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4213, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:10:44,896 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4213, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:44,897 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4213, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 47.22s.
# 2025-06-14 14:10:44,898 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4213, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:10:44,898 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4213, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:44,898 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4213, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:10:46,930 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4229, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 14:10:46,931 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4229, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:46,931 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4229, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 45.83s.
# 2025-06-14 14:10:46,932 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4229, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 14:10:46,932 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4229, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:10:46,932 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4229, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 14:11:02,655 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4171, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:11:02,655 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4171, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:11:02,655 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4171, Channel MI_KNN_Symmetric: Calculated in 19.62s.
# 2025-06-14 14:11:02,661 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4171, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:11:02,661 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4171, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:11:02,661 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4171, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 14:11:02,666 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4171, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:11:02,666 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4171, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:11:02,667 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4171, Channel dFC_StdDev: Calculated in 0.01s.
# 2025-06-14 14:11:03,610 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4219, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:11:03,610 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4219, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:11:03,610 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4219, Channel MI_KNN_Symmetric: Calculated in 19.83s.
# 2025-06-14 14:11:03,640 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4219, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 14:11:03,640 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4219, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:11:03,640 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4219, Channel dFC_AbsDiffMean: Calculated in 0.03s.
# 2025-06-14 14:11:03,733 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4219, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 14:11:03,733 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4219, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:11:03,733 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4219, Channel dFC_StdDev: Calculated in 0.09s.
# 2025-06-14 14:11:05,030 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4213, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 14:11:05,031 - INFO - fmri_connectivity_pipeline.py:874 - S 002_S_4213, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 14:11:05,031 - INFO - fmri_connectivity_pipeline.py:671 - S 002_S_4213, Channel MI_KNN_Symmetric: Calculated in 20.13s.
# 2025-06-14 14:11:05,061 - INFO - fmri_connectivity_pipeline.py:648 - S 002_S_4213, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# ...
# 2025-06-14 16:01:35,518 - INFO - fmri_connectivity_pipeline.py:671 - S 094_S_2238, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 16:01:35,526 - INFO - fmri_connectivity_pipeline.py:648 - S 094_S_2238, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 16:01:35,526 - INFO - fmri_connectivity_pipeline.py:874 - S 094_S_2238, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:01:35,526 - INFO - fmri_connectivity_pipeline.py:671 - S 094_S_2238, Channel dFC_StdDev: Calculated in 0.01s.
# 2025-06-14 16:01:44,281 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6601, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 16:01:44,282 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6601, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:01:44,282 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6601, Channel MI_KNN_Symmetric: Calculated in 26.31s.
# 2025-06-14 16:01:44,292 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6601, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 16:01:44,292 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6601, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:01:44,292 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6601, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 16:01:44,328 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6601, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 16:01:44,328 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6601, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:01:44,328 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6601, Channel dFC_StdDev: Calculated in 0.04s.
# 2025-06-14 16:01:46,855 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6655, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 16:01:46,855 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6655, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:01:46,856 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6655, Channel MI_KNN_Symmetric: Calculated in 27.87s.
# 2025-06-14 16:01:46,930 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6655, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 16:01:46,932 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6655, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:01:46,932 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6655, Channel dFC_AbsDiffMean: Calculated in 0.08s.
# 2025-06-14 16:01:46,984 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6655, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 16:01:46,984 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6655, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:01:46,984 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6655, Channel dFC_StdDev: Calculated in 0.05s.
# 2025-06-14 16:02:11,763 - INFO - fmri_connectivity_pipeline.py:648 - S 094_S_2238, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 16:02:11,763 - INFO - fmri_connectivity_pipeline.py:874 - S 094_S_2238, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:02:11,763 - INFO - fmri_connectivity_pipeline.py:671 - S 094_S_2238, Channel Granger_F_lag1: Calculated in 36.24s.
# 2025-06-14 16:02:11,862 - INFO - fmri_connectivity_pipeline.py:709 - S 094_S_2238: Tensor saved to subject_094_S_2238_conn_tensor.npz in 0.02s.
# Processing Subjects:  57%|█████████▏      | 246/431 [1:56:08<1:46:42, 34.61s/it]2025-06-14 16:02:11,965 - INFO - fmri_connectivity_pipeline.py:544 - S 099_S_2146: Starting processing pipeline.
# 2025-06-14 16:02:12,127 - INFO - fmri_connectivity_pipeline.py:863 - S 099_S_2146: Reordenando series temporales de ROIs ((200, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:02:12,127 - INFO - fmri_connectivity_pipeline.py:1075 - S 099_S_2146: Preprocessing. Input TPs: 200, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 16:02:12,268 - INFO - fmri_connectivity_pipeline.py:1188 - S 099_S_2146: Successfully loaded and preprocessed. Original TPs: 200, Final Shape for conn: (200, 131)
# 2025-06-14 16:02:28,792 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6601, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 16:02:28,792 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6601, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:02:28,792 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6601, Channel Granger_F_lag1: Calculated in 44.46s.
# 2025-06-14 16:02:28,868 - INFO - fmri_connectivity_pipeline.py:709 - S 098_S_6601: Tensor saved to subject_098_S_6601_conn_tensor.npz in 0.01s.
# Processing Subjects:  57%|█████████▏      | 247/431 [1:56:25<1:29:58, 29.34s/it]2025-06-14 16:02:28,998 - INFO - fmri_connectivity_pipeline.py:544 - S 100_S_0069: Starting processing pipeline.
# 2025-06-14 16:02:29,071 - INFO - fmri_connectivity_pipeline.py:863 - S 100_S_0069: Reordenando series temporales de ROIs ((197, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:02:29,071 - INFO - fmri_connectivity_pipeline.py:1075 - S 100_S_0069: Preprocessing. Input TPs: 197, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 16:02:29,190 - INFO - fmri_connectivity_pipeline.py:1188 - S 100_S_0069: Successfully loaded and preprocessed. Original TPs: 197, Final Shape for conn: (197, 131)
# 2025-06-14 16:02:29,672 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6655, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 16:02:29,672 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6655, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:02:29,672 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6655, Channel Granger_F_lag1: Calculated in 42.69s.
# 2025-06-14 16:02:29,760 - INFO - fmri_connectivity_pipeline.py:709 - S 098_S_6655: Tensor saved to subject_098_S_6655_conn_tensor.npz in 0.02s.
# Processing Subjects:  58%|█████████▏      | 248/431 [1:56:26<1:03:23, 20.79s/it]2025-06-14 16:02:29,830 - INFO - fmri_connectivity_pipeline.py:544 - S 100_S_1286: Starting processing pipeline.
# 2025-06-14 16:02:29,913 - INFO - fmri_connectivity_pipeline.py:863 - S 100_S_1286: Reordenando series temporales de ROIs ((197, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:02:29,913 - INFO - fmri_connectivity_pipeline.py:1075 - S 100_S_1286: Preprocessing. Input TPs: 197, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 16:02:30,010 - INFO - fmri_connectivity_pipeline.py:1188 - S 100_S_1286: Successfully loaded and preprocessed. Original TPs: 197, Final Shape for conn: (197, 131)
# 2025-06-14 16:02:43,104 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6658, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 16:02:43,104 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6658, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:02:43,104 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6658, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 73.37s.
# 2025-06-14 16:02:43,106 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6658, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 16:02:43,106 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6658, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:02:43,106 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6658, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 16:03:05,248 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6658, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:05,248 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6658, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:05,248 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6658, Channel MI_KNN_Symmetric: Calculated in 22.14s.
# 2025-06-14 16:03:05,257 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6658, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:05,257 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6658, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:05,257 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6658, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 16:03:05,265 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6658, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:05,265 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6658, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:05,265 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6658, Channel dFC_StdDev: Calculated in 0.01s.
# 2025-06-14 16:03:07,190 - INFO - fmri_connectivity_pipeline.py:648 - S 099_S_2146, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:07,190 - INFO - fmri_connectivity_pipeline.py:874 - S 099_S_2146, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:07,190 - INFO - fmri_connectivity_pipeline.py:671 - S 099_S_2146, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 54.92s.
# 2025-06-14 16:03:07,195 - INFO - fmri_connectivity_pipeline.py:648 - S 099_S_2146, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:07,195 - INFO - fmri_connectivity_pipeline.py:874 - S 099_S_2146, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:07,195 - INFO - fmri_connectivity_pipeline.py:671 - S 099_S_2146, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.01s.
# 2025-06-14 16:03:20,861 - INFO - fmri_connectivity_pipeline.py:648 - S 100_S_0069, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:20,861 - INFO - fmri_connectivity_pipeline.py:874 - S 100_S_0069, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:20,861 - INFO - fmri_connectivity_pipeline.py:671 - S 100_S_0069, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 51.67s.
# 2025-06-14 16:03:20,863 - INFO - fmri_connectivity_pipeline.py:648 - S 100_S_0069, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:20,863 - INFO - fmri_connectivity_pipeline.py:874 - S 100_S_0069, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:20,864 - INFO - fmri_connectivity_pipeline.py:671 - S 100_S_0069, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 16:03:22,228 - INFO - fmri_connectivity_pipeline.py:648 - S 100_S_1286, Channel Pearson_OMST_GCE_Signed_Weighted: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:22,228 - INFO - fmri_connectivity_pipeline.py:874 - S 100_S_1286, Canal Pearson_OMST_GCE_Signed_Weighted: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:22,229 - INFO - fmri_connectivity_pipeline.py:671 - S 100_S_1286, Channel Pearson_OMST_GCE_Signed_Weighted: Calculated in 52.22s.
# 2025-06-14 16:03:22,230 - INFO - fmri_connectivity_pipeline.py:648 - S 100_S_1286, Channel Pearson_Full_FisherZ_Signed: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:22,230 - INFO - fmri_connectivity_pipeline.py:874 - S 100_S_1286, Canal Pearson_Full_FisherZ_Signed: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:22,231 - INFO - fmri_connectivity_pipeline.py:671 - S 100_S_1286, Channel Pearson_Full_FisherZ_Signed: Calculated in 0.00s.
# 2025-06-14 16:03:26,191 - INFO - fmri_connectivity_pipeline.py:648 - S 098_S_6658, Channel Granger_F_lag1: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:26,191 - INFO - fmri_connectivity_pipeline.py:874 - S 098_S_6658, Canal Granger_F_lag1: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:26,191 - INFO - fmri_connectivity_pipeline.py:671 - S 098_S_6658, Channel Granger_F_lag1: Calculated in 20.93s.
# 2025-06-14 16:03:26,269 - INFO - fmri_connectivity_pipeline.py:709 - S 098_S_6658: Tensor saved to subject_098_S_6658_conn_tensor.npz in 0.01s.
# Processing Subjects:  58%|█████████▏      | 249/431 [1:57:23<1:35:34, 31.51s/it]2025-06-14 16:03:26,362 - INFO - fmri_connectivity_pipeline.py:544 - S 100_S_2351: Starting processing pipeline.
# 2025-06-14 16:03:26,426 - INFO - fmri_connectivity_pipeline.py:863 - S 100_S_2351: Reordenando series temporales de ROIs ((140, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:26,426 - INFO - fmri_connectivity_pipeline.py:1075 - S 100_S_2351: Preprocessing. Input TPs: 140, ROIs: 131 (should be 131), TR: 3.0s.
# 2025-06-14 16:03:26,514 - INFO - fmri_connectivity_pipeline.py:1188 - S 100_S_2351: Successfully loaded and preprocessed. Original TPs: 140, Final Shape for conn: (140, 131)
# 2025-06-14 16:03:31,959 - INFO - fmri_connectivity_pipeline.py:648 - S 099_S_2146, Channel MI_KNN_Symmetric: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:31,959 - INFO - fmri_connectivity_pipeline.py:874 - S 099_S_2146, Canal MI_KNN_Symmetric: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:31,959 - INFO - fmri_connectivity_pipeline.py:671 - S 099_S_2146, Channel MI_KNN_Symmetric: Calculated in 24.76s.
# 2025-06-14 16:03:31,971 - INFO - fmri_connectivity_pipeline.py:648 - S 099_S_2146, Channel dFC_AbsDiffMean: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:31,971 - INFO - fmri_connectivity_pipeline.py:874 - S 099_S_2146, Canal dFC_AbsDiffMean: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:31,971 - INFO - fmri_connectivity_pipeline.py:671 - S 099_S_2146, Channel dFC_AbsDiffMean: Calculated in 0.01s.
# 2025-06-14 16:03:31,981 - INFO - fmri_connectivity_pipeline.py:648 - S 099_S_2146, Channel dFC_StdDev: RobustScaler applied (off-diagonal).
# 2025-06-14 16:03:31,981 - INFO - fmri_connectivity_pipeline.py:874 - S 099_S_2146, Canal dFC_StdDev: Reordenando matriz de conectividad ((131, 131)) según el nuevo orden de redes (longitud de índices: 131).
# 2025-06-14 16:03:31,981 - INFO - fmri_connectivity_pipeline.py:671 - S 099_S_2146, Channel dFC_StdDev: Calculated in 0.01s.
